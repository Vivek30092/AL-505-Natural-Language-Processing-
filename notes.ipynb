# %% [markdown]
# ## noise injection

# %% [markdown]
# * for training
# *

# %% [markdown]
# ## stack to stack
# basic vanilla AE
# convolution : deconvolution
#
#
# variational
# stack AE :
# sequence to sequence AE

# %%
dddd
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 print(help.open())
#
# AttributeError: '_Helper' object has no attribute 'open'
