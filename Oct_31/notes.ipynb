# %% [markdown]
# 01_text_processing

# %%
from pytube import YouTube

# Ask user for the YouTube video URL
video_url = input("https://youtu.be/hy3sd9MOAcc?si=QJ0qH5YOMErewp5K")

try:
    # Create YouTube object
    yt = YouTube(video_url)
    
    # Display video details
    print("\n📹 Title:", yt.title)
    print("👤 Channel:", yt.author)
    print("👁️ Views:", yt.views)
    print("🕒 Length:", yt.length, "seconds")
    print("📅 Published on:", yt.publish_date)
    
    # Get the highest resolution stream
    stream = yt.streams.get_highest_resolution()
    
    print("\n⬇️ Downloading video in highest resolution...")
    
    # Download video to current directory
    stream.download()
    
    print("\n✅ Download complete!")
    print("📁 Saved as:", stream.default_filename)

except Exception as e:
    print("\n❌ An error occurred:", e)
# Out:
# ❌ An error occurred: HTTP Error 400: Bad Request

# %%
pip install pytube
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#   Using cached pytube-15.0.0-py3-none-any.whl.metadata (5.0 kB)
# Using cached pytube-15.0.0-py3-none-any.whl (57 kB)
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip
